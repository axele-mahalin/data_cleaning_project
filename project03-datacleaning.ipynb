# %% [markdown]
# # Importing data

# %%
import pandas as pd
import numpy as np
import re

# %%
df_og = pd.read_csv('6 - Primary Education.csv')

# %%
df = df_og.copy()

# %%
df.head()
# Out:
#   ISO3 Countries and areas Region Sub-region              Income Group  Total
# 0  AGO              Angola    SSA        ESA  Lower middle income (LM)   0.15  \
# 1  ARG           Argentina    LAC        LAC  Upper middle income (UM)   0.39
# 2  ARM             Armenia    ECA       EECA  Upper middle income (UM)   0.81
# 3  BGD          Bangladesh     SA         SA  Lower middle income (LM)   0.34
# 4  BRB            Barbados    LAC        LAC           High income (H)   0.63
#
#    Residence Rural  Residence Urban  Wealth quintile Poorest
# 0             0.02             0.22                     0.00  \
# 1              NaN              NaN                      NaN
# 2             0.69             0.89                     0.46
# 3             0.30             0.49                     0.07
# 4             0.54             0.68                     0.09
#
#    Wealth quintile Richest                        Data source Time period
# ...

# %%
# drop useless columns
df.drop(['Sub-region','ISO3'], axis=1, inplace=True)

# %%
# drop rows with null data 
df = df.dropna()

# %%
# filter only the rows for which the data is over a single year
# delete rows where len(year) != 4

df["Time period"] = df["Time period"].astype('str')

df = df[df["Time period"].apply(len) ==4] 

df
# Out:
#                  Countries and areas Region              Income Group  Total
# 3                         Bangladesh     SA  Lower middle income (LM)   0.34  \
# 4                           Barbados    LAC           High income (H)   0.63
# 8                             Brazil    LAC  Upper middle income (UM)   0.82
# 9                           Bulgaria    ECA  Upper middle income (UM)   0.73
# 10                      Burkina Faso    SSA            Low income (L)   0.01
# 11                          Cameroon    SSA  Lower middle income (LM)   0.04
# 13                              Chad    SSA            Low income (L)   0.02
# 14                             Chile    LAC           High income (H)   0.86
# 17                        Costa Rica    LAC  Upper middle income (UM)   0.70
# 18                     Côte d'Ivoire    SSA  Lower middle income (LM)   0.02
# 19                              Cuba    LAC  Upper middle income (UM)   0.05
# ...

# %%
# drop outliers value


# Outliers in Time Period
df = df[df["Time period"] != "2562"]

df = df[df["Time period"] != "2076"]

#Keep only indexes that are between 0 and 1
df = df[df["Total"] <= 1]

df = df[df["Residence Rural"] <= 1] 

df = df[df["Residence Urban"] <= 1] 

df = df[df["Wealth quintile Poorest"] <= 1] 

df = df[df["Wealth quintile Richest"] <= 1] 


df
# Out:
#                  Countries and areas Region              Income Group  Total
# 3                         Bangladesh     SA  Lower middle income (LM)   0.34  \
# 4                           Barbados    LAC           High income (H)   0.63
# 8                             Brazil    LAC  Upper middle income (UM)   0.82
# 9                           Bulgaria    ECA  Upper middle income (UM)   0.73
# 10                      Burkina Faso    SSA            Low income (L)   0.01
# 11                          Cameroon    SSA  Lower middle income (LM)   0.04
# 13                              Chad    SSA            Low income (L)   0.02
# 14                             Chile    LAC           High income (H)   0.86
# 17                        Costa Rica    LAC  Upper middle income (UM)   0.70
# 18                     Côte d'Ivoire    SSA  Lower middle income (LM)   0.02
# 19                              Cuba    LAC  Upper middle income (UM)   0.05
# ...

# %%
# Correct index

df.reset_index(drop=True)
# Out:
#                  Countries and areas Region              Income Group  Total
# 0                         Bangladesh     SA  Lower middle income (LM)   0.34  \
# 1                           Barbados    LAC           High income (H)   0.63
# 2                             Brazil    LAC  Upper middle income (UM)   0.82
# 3                           Bulgaria    ECA  Upper middle income (UM)   0.73
# 4                       Burkina Faso    SSA            Low income (L)   0.01
# 5                           Cameroon    SSA  Lower middle income (LM)   0.04
# 6                               Chad    SSA            Low income (L)   0.02
# 7                              Chile    LAC           High income (H)   0.86
# 8                         Costa Rica    LAC  Upper middle income (UM)   0.70
# 9                      Côte d'Ivoire    SSA  Lower middle income (LM)   0.02
# 10                              Cuba    LAC  Upper middle income (UM)   0.05
# ...

# %%
df.to_csv('primary_education_cleane.csv')
